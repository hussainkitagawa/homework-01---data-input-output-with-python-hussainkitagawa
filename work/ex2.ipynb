# %%
#import Numpy
import os
import numpy as np

# Import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
# %matplotlib inline

#Now, import the FITS module inside Astropy
from astropy.io import fits

#Work directory
work_dir = os.getcwd()
print("Work dir %s" % work_dir)

#find main directory
main_dir =os.path.dirname(work_dir)
print("Main directory is %s" % main_dir)

#find data directory
data_dir = os.path.join(main_dir,"data")
print("data dir is %s" % data_dir)

#Create result
results_dir = os.path.join(main_dir,"results")
##if the directory does not exist, you can create it
if not os.path.exists(results_dir):
    os.mkdir(results_dir)
    print("Directory %s created !" % results_dir)
# Out:
# Work dir /Users/kitagawa/lecture/grb/230420/homework-01---data-input-output-with-python-hussainkitagawa/work
# Main directory is /Users/kitagawa/lecture/grb/230420/homework-01---data-input-output-with-python-hussainkitagawa
# data dir is /Users/kitagawa/lecture/grb/230420/homework-01---data-input-output-with-python-hussainkitagawa/data

# %%
import glob

#in glob we put the items to seach, such as: data/*fits
fits_file_list = glob.glob(os.path.join(data_dir,"*.fits"))

#here we go!
print(fits_file_list)
# Out:
# ['/Users/kitagawa/lecture/grb/230420/homework-01---data-input-output-with-python-hussainkitagawa/data/fermi_lat_3fgl_gll_psc_v16.fits', '/Users/kitagawa/lecture/grb/230420/homework-01---data-input-output-with-python-hussainkitagawa/data/lat_photons_3c279.fits', '/Users/kitagawa/lecture/grb/230420/homework-01---data-input-output-with-python-hussainkitagawa/data/horse_head_image.fits', '/Users/kitagawa/lecture/grb/230420/homework-01---data-input-output-with-python-hussainkitagawa/data/2PC_catalog_v04.fits']

# %%
#define the input file
input_filename = os.path.join(data_dir,"2PC_catalog_v04.fits")

#First, you can open the file and check the information contained in it
fits_info = fits.open(input_filename)

#Look at the number of HDU, in this case 5
fits_info.info()
# Out:
# Filename: /Users/kitagawa/lecture/grb/230420/homework-01---data-input-output-with-python-hussainkitagawa/data/2PC_catalog_v04.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       8   ()
#   1  PULSAR_CATALOG    1 BinTableHDU    402   117R x 88C   [11A, E, E, E, E, E, E, D, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, 3A, I, E, E, I, E, E, E, D, E, E, E, E, E, E, E, E, E, E, E, E, E, E, I, I, 2A, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, 2A, 3A, 1A, E, E, E, E, E, E, E, E, E, E, 3A, 1A, 5A]
#   2  SPECTRAL      1 BinTableHDU    194   117R x 38C   [11A, 1A, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E]
#   3  OFF_PEAK      1 BinTableHDU    226   117R x 44C   [14A, 2A, E, E, E, E, E, E, E, E, 16A, E, E, E, E, E, E, E, E, E, E, E, E, E, 9A, E, E, E, E, E, E, E, E, E, E, E, 14E, 14E, 14E, 14E, 14E, 14E, 14E, 14E]
#   4  REFERENCES    1 BinTableHDU     72   100R x 4C   [3A, 44A, 53A, 134A]

# %%
#Now, we want to read the HDU 1. We can do by specifying the "ext" parameter
data, header = fits.getdata(input_filename, ext=1,header=True)

#and we can look at the header
header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                  347 / width of table in bytes
# NAXIS2  =                  117 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                   88 / number of fields in each row
# TTYPE1  = 'PSR_Name'           / Pulsar name
# TFORM1  = '11A     '           / data format of field: ASCII Character
# TTYPE2  = 'RAJ2000 '           / Right Ascension (J2000)
# TFORM2  = 'E       '           / data format of field: 4-byte REAL
# TUNIT2  = 'deg     '
# TTYPE3  = 'DEJ2000 '           / Declination (J2000)
# TFORM3  = 'E       '           / data format of field: 4-byte REAL
# TUNIT3  = 'deg     '
# TTYPE4  = 'GLON    '           / Galactic longitude
# TFORM4  = 'E       '           / data format of field: 4-byte REAL
# TUNIT4  = 'deg     '
# TTYPE5  = 'GLAT    '           / Galactic latitude
# TFORM5  = 'E       '           / data format of field: 4-byte REAL
# TUNIT5  = 'deg     '
# TTYPE6  = 'Period  '           / Pulsar period
# TFORM6  = 'E       '           / data format of field: 4-byte REAL
# TUNIT6  = 'ms      '
# TTYPE7  = 'P_Dot   '           / Period first derivative
# TFORM7  = 'E       '           / data format of field: 4-byte REAL
# TUNIT7  = 's/s     '
# TTYPE8  = 'E_Dot   '           / Spin down luminosity
# TFORM8  = 'D       '           / data format of field: 8-byte DOUBLE
# TUNIT8  = 'erg/s   '
# TTYPE9  = 'F100    '           / Photon flux for 100 MeV-100 GeV
# TFORM9  = 'E       '           / data format of field: 4-byte REAL
# TUNIT9  = 'ph/cm**2/s'
# TTYPE10 = 'Unc_F100'           / Photon flux error
# TFORM10 = 'E       '           / data format of field: 4-byte REAL
# TUNIT10 = 'ph/cm**2/s'
# TTYPE11 = 'G100    '           / Energy flux for 100 MeV-100 GeV
# TFORM11 = 'E       '           / data format of field: 4-byte REAL
# TUNIT11 = 'erg/cm**2/s'
# TTYPE12 = 'Unc_G100'           / Energy flux error
# TFORM12 = 'E       '           / data format of field: 4-byte REAL
# TUNIT12 = 'erg/cm**2/s'
# TTYPE13 = 'TS_DC   '           / Test statistic of DC source
# TFORM13 = 'E       '           / data format of field: 4-byte REAL
# TTYPE14 = 'TS_Cutoff'          / Test statistic of spectral cutoff
# TFORM14 = 'E       '           / data format of field: 4-byte REAL
# TTYPE15 = 'TS_bfree'           / Change in TS when photon index is fitted
# TFORM15 = 'E       '           / data format of field: 4-byte REAL
# TTYPE16 = 'Photon_Index'       / Photon index for the PLEC spectral model
# TFORM16 = 'E       '           / data format of field: 4-byte REAL
# TTYPE17 = 'Unc_Photon_Index'   / Photon index error for PLEC model
# TFORM17 = 'E       '           / data format of field: 4-byte REAL
# TTYPE18 = 'Cutoff  '           / Cutoff energy
# TFORM18 = 'E       '           / data format of field: 4-byte REAL
# TUNIT18 = 'MeV     '
# TTYPE19 = 'Unc_Cutoff'         / Cutoff energy error
# TFORM19 = 'E       '           / data format of field: 4-byte REAL
# TUNIT19 = 'MeV     '
# TTYPE20 = 'Distance'           / Distance to pulsar
# TFORM20 = 'E       '           / data format of field: 4-byte REAL
# TUNIT20 = 'kpc     '
# TTYPE21 = 'Neg_Unc_Distance'   / Negative error on distance measurement, NULL fo
# TFORM21 = 'E       '           / data format of field: 4-byte REAL
# TUNIT21 = 'kpc     '
# TTYPE22 = 'Pos_Unc_Distance'   / Positive error on distance measurement, NULL fo
# TFORM22 = 'E       '           / data format of field: 4-byte REAL
# TUNIT22 = 'kpc     '
# TTYPE23 = 'UL_Distance'        / Upper limit for distance to pulsar
# TFORM23 = 'E       '           / data format of field: 4-byte REAL
# TUNIT23 = 'kpc     '
# TTYPE24 = 'Distance_Method'    / Method used for distance determination
# TFORM24 = '3A      '           / data format of field: ASCII Character
# TTYPE25 = 'Distance_Ref'       / Reference for distance measurement
# TFORM25 = 'I       '           / data format of field: 2-byte INTEGER
# TTYPE26 = 'Prop_Motion'        / Proper motion
# TFORM26 = 'E       '           / data format of field: 4-byte REAL
# TUNIT26 = 'mas/yr  '
# TTYPE27 = 'Unc_Prop_Motion'    / Proper motion error
# TFORM27 = 'E       '           / data format of field: 4-byte REAL
# TUNIT27 = 'mas/yr  '
# TTYPE28 = 'Prop_Motion_Ref'    / Reference for proper motion
# TFORM28 = 'I       '           / data format of field: 2-byte INTEGER
# TTYPE29 = 'P_Dot_Int'          / Intrinsic P-dot
# TFORM29 = 'E       '           / data format of field: 4-byte REAL
# TUNIT29 = 's/s     '
# TTYPE30 = 'Neg_Unc_P_Dot_Int'  / Intrinsic P-dot negative error
# TFORM30 = 'E       '           / data format of field: 4-byte REAL
# TUNIT30 = 's/s     '
# TTYPE31 = 'Pos_Unc_P_Dot_Int'  / Intrinsic P-dot positive error
# TFORM31 = 'E       '           / data format of field: 4-byte REAL
# TUNIT31 = 's/s     '
# TTYPE32 = 'E_Dot_Int'          / Intrinsic E-dot
# TFORM32 = 'D       '           / data format of field: 8-byte DOUBLE
# TUNIT32 = 'erg/s   '
# TTYPE33 = 'Neg_Unc_E_Dot_Int'  / Intrinsic E-dot negative error
# TFORM33 = 'E       '           / data format of field: 4-byte REAL
# TUNIT33 = 'erg/s   '
# TTYPE34 = 'Pos_Unc_E_Dot_Int'  / Intrinsic E-dot positive error
# TFORM34 = 'E       '           / data format of field: 4-byte REAL
# TUNIT34 = 'erg/s   '
# TTYPE35 = 'Luminosity'         / Pulsar luminosity
# TFORM35 = 'E       '           / data format of field: 4-byte REAL
# TUNIT35 = 'erg/s   '
# TTYPE36 = 'Unc_Luminosity'     / Error on luminosity due to fit, NULL for UL
# TFORM36 = 'E       '           / data format of field: 4-byte REAL
# TUNIT36 = 'erg/s   '
# TTYPE37 = 'Neg_Sys_Luminosity' / Negative luminosity error from distance measure
# TFORM37 = 'E       '           / data format of field: 4-byte REAL
# TUNIT37 = 'erg/s   '
# TTYPE38 = 'Pos_Sys_Luminosity' / Positive luminosity error from distance measure
# TFORM38 = 'E       '           / data format of field: 4-byte REAL
# TUNIT38 = 'erg/s   '
# TTYPE39 = 'UL_Luminosity'      / Upper limit for pulsar luminosity
# TFORM39 = 'E       '           / data format of field: 4-byte REAL
# TUNIT39 = 'erg/s   '
# TTYPE40 = 'Efficiency'         / Pulsar efficiency
# TFORM40 = 'E       '           / data format of field: 4-byte REAL
# TUNIT40 = 'percent '
# TTYPE41 = 'Unc_Efficiency'     / Error on efficiency due to fit, NULL for UL
# TFORM41 = 'E       '           / data format of field: 4-byte REAL
# TUNIT41 = 'percent '
# TTYPE42 = 'Neg_Sys_Efficiency' / Negative efficiency error from distance measure
# TFORM42 = 'E       '           / data format of field: 4-byte REAL
# TUNIT42 = 'percent '
# TTYPE43 = 'Pos_Sys_Efficiency' / Positive efficiency error from distance measure
# TFORM43 = 'E       '           / data format of field: 4-byte REAL
# TUNIT43 = 'percent '
# TTYPE44 = 'UL_Efficiency'      / Upper limit for pulsar efficiency
# TFORM44 = 'E       '           / data format of field: 4-byte REAL
# TUNIT44 = 'percent '
# TTYPE45 = 'S1400   '           / Radio flux at 1400 MHz (may be extrapolated)
# TFORM45 = 'E       '           / data format of field: 4-byte REAL
# TUNIT45 = 'mJy     '
# TTYPE46 = 'UL_S1400'           / Upper Limit value for S1400
# TFORM46 = 'E       '           / data format of field: 4-byte REAL
# TUNIT46 = 'mJy     '
# TTYPE47 = 'S1400_Ref'          / Radio flux reference
# TFORM47 = 'I       '           / data format of field: 2-byte INTEGER
# TTYPE48 = 'Num_Peaks'          / Number of peaks in the gamma-ray profile
# TFORM48 = 'I       '           / data format of field: 2-byte INTEGER
# TTYPE49 = 'Shift_Method'       / Method used to choose the radio fiducial phase
# TFORM49 = '2A      '           / data format of field: ASCII Character
# TTYPE50 = 'Radio_Lag'          / Phase separation between peak 1 and radio peak
# TFORM50 = 'E       '           / data format of field: 4-byte REAL
# TTYPE51 = 'Unc_Radio_Lag'      / Error on phase separation between peak 1 and ra
# TFORM51 = 'E       '           / data format of field: 4-byte REAL
# TTYPE52 = 'Peak_Sep'           / Phase sep between peaks (DELTA), NULL for singl
# TFORM52 = 'E       '           / data format of field: 4-byte REAL
# TTYPE53 = 'Unc_Peak_Sep'       / Error on phase separation between peaks
# TFORM53 = 'E       '           / data format of field: 4-byte REAL
# TTYPE54 = 'HWHM_P1_L'          / Half-width half-max of leading (left) first pea
# TFORM54 = 'E       '           / data format of field: 4-byte REAL
# TTYPE55 = 'Unc_HWHM_P1_L'      / Uncertainty on HWHM_P1_L
# TFORM55 = 'E       '           / data format of field: 4-byte REAL
# TTYPE56 = 'HWHM_P1_R'          / Half-width half-max of trailing (right) first p
# TFORM56 = 'E       '           / data format of field: 4-byte REAL
# TTYPE57 = 'Unc_HWHM_P1_R'      / Uncertainty on HWHM_P1_R
# TFORM57 = 'E       '           / data format of field: 4-byte REAL
# TTYPE58 = 'HWHM_P2_L'          / Half-width half-max of leading (left) second pe
# TFORM58 = 'E       '           / data format of field: 4-byte REAL
# TTYPE59 = 'Unc_HWHM_P2_L'      / Uncertainty on HWHM_P2_L
# TFORM59 = 'E       '           / data format of field: 4-byte REAL
# TTYPE60 = 'HWHM_P2_R'          / Half-width half-max of trailing (right) second
# TFORM60 = 'E       '           / data format of field: 4-byte REAL
# TTYPE61 = 'Unc_HWHM_P2_R'      / Uncertainty on HWHM_P2_R
# TFORM61 = 'E       '           / data format of field: 4-byte REAL
# TTYPE62 = 'H_ColDensity'       / Hydrogen column density
# TFORM62 = 'E       '           / data format of field: 4-byte REAL
# TUNIT62 = '1/cm**2 '
# TTYPE63 = 'Neg_Unc_H_ColDensity' / Negative error for hydrogen column density, N
# TFORM63 = 'E       '           / data format of field: 4-byte REAL
# TUNIT63 = '1/cm**2 '
# TTYPE64 = 'Pos_Unc_H_ColDensity' / Positive error for hydrogen column density, N
# TFORM64 = 'E       '           / data format of field: 4-byte REAL
# TUNIT64 = '1/cm**2 '
# TTYPE65 = 'UL_H_ColDensity'    / Upper limit for hydrogen column density
# TFORM65 = 'E       '           / data format of field: 4-byte REAL
# TUNIT65 = '1/cm**2 '
# TTYPE66 = 'XFlux_NonTherm'     / Nonthermal X-ray energy flux
# TFORM66 = 'E       '           / data format of field: 4-byte REAL
# TUNIT66 = 'erg/cm**2/s'
# TTYPE67 = 'Neg_Unc_XFlux_NonTherm' / Negative error on nonthermal X-ray flux, NU
# TFORM67 = 'E       '           / data format of field: 4-byte REAL
# TUNIT67 = 'erg/cm**2/s'
# TTYPE68 = 'Pos_Unc_XFlux_NonTherm' / Positive error on nonthermal X-ray flux, NU
# TFORM68 = 'E       '           / data format of field: 4-byte REAL
# TUNIT68 = 'erg/cm**2/s'
# TTYPE69 = 'UL_XFlux_NonTherm'  / Upper limit for nonthermal X-ray energy flux
# TFORM69 = 'E       '           / data format of field: 4-byte REAL
# TUNIT69 = 'erg/cm**2/s'
# TTYPE70 = 'XFlux_PWN'          / Estimated X-ray flux from associated plerion
# TFORM70 = 'E       '           / data format of field: 4-byte REAL
# TUNIT70 = 'erg/cm**2/s'
# TTYPE71 = 'Neg_Unc_XFlux_PWN'  / Negative error for plerion X-ray flux
# TFORM71 = 'E       '           / data format of field: 4-byte REAL
# TUNIT71 = 'erg/cm**2/s'
# TTYPE72 = 'Pos_Unc_XFlux_PWN'  / Positive error for plerion X-ray flux
# TFORM72 = 'E       '           / data format of field: 4-byte REAL
# TUNIT72 = 'erg/cm**2/s'
# TTYPE73 = 'X_Qual  '           / Data quality flag for X-ray observations
# TFORM73 = '2A      '           / data format of field: ASCII Character
# TTYPE74 = 'Opt_Object'         / Type Bin, UL, Psr(*=pulsed,+=candidate), Compan
# TFORM74 = '3A      '           / data format of field: ASCII Character
# TTYPE75 = 'Opt_Band'           / Filter used for optical observation
# TFORM75 = '1A      '           / data format of field: ASCII Character
# TTYPE76 = 'Opt_Mag '           / Optical magnitude
# TFORM76 = 'E       '           / data format of field: 4-byte REAL
# TTYPE77 = 'LL_Opt_Mag'         / 'Y' if optical magnitude is a lower limit
# TFORM77 = 'E       '           / data format of field: 4-byte REAL
# TTYPE78 = 'Extinction'         / Optical extinction
# TFORM78 = 'E       '           / data format of field: 4-byte REAL
# TTYPE79 = 'Neg_Unc_Extinction' / Negative error on opt extinction from distance
# TFORM79 = 'E       '           / data format of field: 4-byte REAL
# TTYPE80 = 'Pos_Unc_Extinction' / Positive error on opt extinction from distance
# TFORM80 = 'E       '           / data format of field: 4-byte REAL
# TTYPE81 = 'UL_Extinction'      / Upper limit for optical extinction
# TFORM81 = 'E       '           / data format of field: 4-byte REAL
# TTYPE82 = 'Corr_OptFlux'       / Corrected optical energy flux
# TFORM82 = 'E       '           / data format of field: 4-byte REAL
# TUNIT82 = 'erg/cm**2/s'
# TTYPE83 = 'Neg_Unc_Corr_OptFlux' / Negative error on optical energy flux
# TFORM83 = 'E       '           / data format of field: 4-byte REAL
# TUNIT83 = 'erg/cm**2/s'
# TTYPE84 = 'Pos_Unc_Corr_OptFlux' / Positive error on optical energy flux
# TFORM84 = 'E       '           / data format of field: 4-byte REAL
# TUNIT84 = 'erg/cm**2/s'
# TTYPE85 = 'UL_Corr_OptFlux'    / Upper limit for optical energy flux
# TFORM85 = 'E       '           / data format of field: 4-byte REAL
# TUNIT85 = 'erg/cm**2/s'
# TTYPE86 = 'Type    '           / MSP or Young radio-quiet/radio-loud pulsar
# TFORM86 = '3A      '           / data format of field: ASCII Character
# TTYPE87 = 'Binary  '           / Y indicates the pulsar is in a binary system
# TFORM87 = '1A      '           / data format of field: ASCII Character
# TTYPE88 = 'History '           / Discovered in Radio, X-rays or Gamma-rays
# TFORM88 = '5A      '           / data format of field: ASCII Character
# COMMENT
# EMIN    = '100     '           / Minimum energy used in spectral analyses (in Me
# EMAX    = '100000  '           / Maximum energy used in spectral analyses (in Me
# COMMENT
# TBUCD1  = 'meta.main;meta.id'  / UCD for PSR_Name
# TDISP2  = 'F8.4    '
# TBUCD2  = 'pos.eq.ra;meta.main' / UCD for RAJ2000
# TDISP3  = 'F8.4    '
# TBUCD3  = 'pos.eq.dec;meta.main' / UCD for DEJ2000
# TDISP4  = 'F6.2    '
# TBUCD4  = 'pos.galactic.lon'   / UCD for GLON
# TDISP5  = 'F6.2    '
# TBUCD5  = 'pos.galactic.lat'   / UCD for GLAT
# TDISP6  = 'F6.2    '
# TBUCD6  = 'time.period'        / UCD for Period
# TDISP7  = 'E10.4   '
# TDISP8  = 'E10.5   '
# TDISP9  = 'E10.4   '
# TBUCD9  = 'phot.count;em.gamma' / UCD for F100
# TDISP10 = 'E9.3    '
# TBUCD10 = 'phot.count;em.gamma;stat.error' / UCD for Unc_F100
# TDISP11 = 'E10.4   '
# TBUCD11 = 'phot.flux;em.gamma' / UCD for G100
# TDISP12 = 'E7.1    '
# TBUCD12 = 'phot.flux;em.gamma;stat.error' / UCD for Unc_G100
# TDISP13 = 'F7.0    '
# TBUCD13 = 'stat.value'         / UCD for TS_DC
# TDISP14 = 'F7.0    '
# TBUCD14 = 'stat.value'         / UCD for TS_Cutoff
# TDISP15 = 'F7.0    '
# TBUCD15 = 'stat.value'         / UCD for TS_bfree
# TDISP16 = 'F5.3    '
# TBUCD16 = 'spect.index'        / UCD for Photon_Index
# TDISP17 = 'F5.3    '
# TBUCD17 = 'spect.index;stat.error' / UCD for Unc_Photon_Index
# TBUCD18 = 'em.energy;em.gamma' / UCD for Cutoff
# TBUCD19 = 'em.energy;em.gamma;stat.error' / UCD for Unc_Cutoff
# TDISP20 = 'F6.3    '
# TBUCD20 = 'pos.distance'       / UCD for Distance
# TDISP21 = 'F6.3    '
# TBUCD21 = 'pos.distance;stat.error.sys;stat.min' / UCD for Neg_Unc_Distance
# TDISP22 = 'F6.3    '
# TBUCD22 = 'pos.distance;stat.error.sys;stat.max' / UCD for Pos_Unc_Distance
# TDISP23 = 'F6.3    '
# TBUCD23 = 'pos.distance'       / UCD for UL_Distance
# TBUCD25 = 'pos.distance;meta.bib' / UCD for Distance_Ref
# TDISP26 = 'F6.2    '
# TBUCD26 = 'pos.pm  '           / UCD for Prop_Motion
# TDISP27 = 'F6.2    '
# TBUCD27 = 'pos.pm;stat.error'  / UCD for Unc_Prop_Motion
# TBUCD28 = 'pos.pm;meta.bib'    / UCD for Prop_Motion_Ref
# TDISP29 = 'E9.3    '
# TDISP30 = 'E9.3    '
# TDISP31 = 'E9.3    '
# TDISP32 = 'E9.3    '
# TDISP33 = 'E9.3    '
# TDISP34 = 'E10.4    '
# TDISP35 = 'E10.4   '
# TBUCD35 = 'phys.luminosity;em.gamma' / UCD for Luminosity
# TDISP36 = 'E7.1    '
# TBUCD36 = 'phys.luminosity;em.gamma;stat.error' / UCD for Unc_Luminosity
# TDISP37 = 'E10.4   '
# TBUCD37 = 'phys.luminosity;em.gamma;stat.error.sys;stat.min' / UCD for Neg_Sys_L
# TDISP38 = 'E10.4   '
# TBUCD38 = 'phys.luminosity;em.gamma;stat.error.sys;stat.max' / UCD for Pos_Sys_L
# TDISP39 = 'E10.4   '
# TBUCD39 = 'phys.luminosity;em.gamma' / UCD for UL_Luminosity
# TDISP40 = 'F7.4    '
# TDISP41 = 'F7.4    '
# TDISP42 = 'F7.4    '
# TDISP43 = 'F7.4    '
# TDISP44 = 'F7.4    '
# TDISP45 = 'F8.3    '
# TBUCD45 = 'phot.flux;em.radio.750-1500MHz' / UCD for S1400
# TDISP46 = 'F8.3    '
# TBUCD46 = 'phot.flux;em.radio.750-1500MHz' / UCD for S1400
# TBUCD47 = 'phot.flux;em.radio.750-1500MHz;meta.bib' / UCD for S1400_Ref
# TDISP50 = 'F5.3    '
# TBUCD50 = 'time.phase'         / UCD for Radio_Lag
# TDISP51 = 'F6.4    '
# TBUCD51 = 'time.phase;stat.error.sys' / UCD for Unc_Radio_Lag
# TDISP52 = 'F5.3    '
# TBUCD52 = 'time.phase'         / UCD for Peak_Sep
# TDISP53 = 'F5.3    '
# TBUCD53 = 'time.phase;stat.error.sys' / UCD for Unc_Peak_Sep
# TDISP54 = 'F6.4    '
# TBUCD54 = 'time.phase'         / UCD for HWHM_P1_L
# TDISP55 = 'F6.4    '
# TBUCD55 = 'time.phase;stat.error.sys' / UCD for Unc_HWHM_P1_L
# TDISP56 = 'F6.4    '
# TBUCD56 = 'time.phase'         / UCD for HWHM_P1_R
# TDISP57 = 'F6.4    '
# TBUCD57 = 'time.phase;stat.error.sys' / UCD for Unc_HWHM_P1_R
# TDISP58 = 'F6.4    '
# TBUCD58 = 'time.phase'         / UCD for HWHM_P2_L
# TDISP59 = 'F6.4    '
# TBUCD59 = 'time.phase;stat.error.sys' / UCD for Unc_HWHM_P2_L
# TDISP60 = 'F6.4    '
# TBUCD60 = 'time.phase'         / UCD for HWHM_P2_R
# TDISP61 = 'F6.4    '
# TBUCD61 = 'time.phase;stat.error.sys' / UCD for Unc_HWHM_P2_R
# TDISP62 = 'E8.2    '
# TBUCD62 = 'phys.columnDensity' / UCD for H_ColDensity
# TDISP63 = 'E8.2    '
# TBUCD63 = 'phys.columnDensity;stat.error.sys;stat.min' / UCD for Neg_Unc_H_ColDe
# TDISP64 = 'E8.2    '
# TBUCD64 = 'phys.columnDensity;stat.error.sys;stat.max' / UCD for Pos_Unc_H_ColDe
# TDISP65 = 'E8.2    '
# TBUCD65 = 'phys.columnDensity' / UCD for UL_H_ColDensity
# TDISP66 = 'E8.2    '
# TBUCD66 = 'phot.flux;em.X-ray' / UCD for XFlux_NonTherm
# TDISP67 = 'E8.2    '
# TBUCD67 = 'phot.flux;em.X-ray;stat.error.sys' / UCD for Neg_Unc_XFlux_NonTherm
# TDISP68 = 'E8.2    '
# TBUCD68 = 'phot.flux;em.X-ray;stat.error.sys' / UCD for Pos_Unc_XFlux_NonTherm
# TDISP69 = 'E8.2    '
# TBUCD69 = 'phot.flux;em.X-ray' / UCD for UL_XFlux_NonTherm
# TDISP70 = 'E8.2    '
# TBUCD70 = 'phot.flux;em.X-ray' / UCD for XFlux_PWN
# TDISP71 = 'E8.2    '
# TBUCD71 = 'phot.flux;em.X-ray;stat.error.sys' / UCD for Neg_Unc_XFlux_PWN
# TDISP72 = 'E8.2    '
# TBUCD72 = 'phot.flux;em.X-ray;stat.error.sys' / UCD for Pos_Unc_XFlux_PWN
# TBUCD74 = 'em.X-ray:meta.code.qualt' / UCD for X_Qual
# TBUCD75 = 'instr.filter'       / UCD for Opt_Band
# TDISP76 = 'F5.2    '
# TBUCD76 = 'phot.mag;em.opt'    / UCD for Opt_Mag
# TDISP77 = 'F5.2    '
# TBUCD77 = 'phot.mag;em.opt;stat.min;meta.code' / UCD for LL_Opt_Mag
# TDISP78 = 'F5.2    '
# TBUCD78 = 'phys.absorption;em.opt' / UCD for Extinction
# TDISP79 = 'F4.2    '
# TBUCD79 = 'phys.absorption;em.opt;stat.error.sys;stat.min' / UCD for Neg_Unc_Ext
# TDISP80 = 'F4.2    '
# TBUCD80 = 'phys.absorption;em.opt;stat.error.sys;stat.max' / UCD for Pos_Unc_Ext
# TDISP81 = 'F5.2    '
# TBUCD81 = 'phys.absorption;em.opt' / UCD for UL_Extinction
# TDISP82 = 'E8.2    '
# TBUCD82 = 'phot.flux;em.opt.V' / UCD for Corr_OptFlux
# TDISP83 = 'E8.2    '
# TBUCD83 = 'phot.flux;em.opt.V;stat.error.sys;stat.min' / UCD for Neg_Unc_Corr_Op
# TDISP84 = 'E8.2    '
# TBUCD84 = 'phot.flux;em.opt.V;stat.error.sys;stat.max' / UCD for Pos_Unc_Corr_Op
# TDISP85 = 'E8.2    '
# TBUCD85 = 'phot.flux;em.opt.V' / UCD for UL_Corr_OptFlux
# TBUCD87 = 'meta.code.multip'   / UCD for Binary
# COMMENT
# COMMENT
# COMMENT
# TELESCOP= 'Fermi   '           / name of telescope generating data
# INSTRUME= 'LAT     '           / name of instrument generating data
# EQUINOX =               2000.0 / equinox for ra and dec
# RADECSYS= 'FK5     '           / world coord. system for this file (FK5 or FK4)
# TIMEUNIT= 's       '           / units for the time related keywords
# TIMESYS = 'TT      '           / type of time system that is used
# OBSERVER= 'Peter Michelson'    / LAT PI
# ORIGIN  = 'LISOC   '           / name of organization making file
# NUMEXT  =                    5 / number of HDUs in this file
# EXTNAME = 'PULSAR_CATALOG'     / name of this binary table extension
# FILENAME= '2PC_catalog_v04.fits' / name of this file
# VERSION = 'v04     '           / release version of the file
# CREATOR = 'Elizabeth Ferrara ' / name of person creating file
# DATE    = '2013-07-24'         / file creation date (UTC)
# COMMENT
# CHECKSUM= 'WYRLXWPIWWPIWWPI'   / HDU checksum updated 2013-07-24T22:12:38
# DATASUM = '2905119193'         / data unit checksum updated 2013-07-24T22:12:38
